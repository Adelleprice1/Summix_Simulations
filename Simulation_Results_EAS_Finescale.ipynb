# %%
sims <- read.table("/mnt/c/Users/adell/Desktop/Fine_Scale_Simulations_EAS_fst.002.testrun.text", header = TRUE)
acc_frame = data.frame(sims[,grep('accuracy', names(sims))])
names(acc_frame) <- gsub("_accuracy", "", names(acc_frame))

# %% [markdown]
# **Figure 1:** Fine scale groups Japanese(1KG)&Japanese(HGDP) and Han Chinese(1KG)&Han(HGDP) true proportions set on interval between .499 and .501; all other fine scale group true proportions set as 0. <br>100 simluation replicates completed.<br>
# Here, Summix tends to underestimate proprotions of both Japanese(1KG)&Japanese(HGDP) and Han Chinese(1KG)&Han(HGDP) while Summix overestimates proportions all other fine scale scale groups that have true proportions of 0. Accuracy for each fine scale group is between -.0015 and .0015 (Summix estimate - parameter) for all estimates.

# %%
lilsims1 <- sims[sims$P_Num == "1",]
lilsims_acc1 <- data.frame(lilsims1[,grep('accuracy', names(lilsims1))])
names(lilsims_acc1) <- gsub("_accuracy", "", names(lilsims_acc1))
boxplot(lilsims_acc1, las = 3, cex.axis = .6, tick = FALSE, yaxp = c(-.003, .003, 10))
# Out:
# plot without title

# %% [markdown]
# <br><br><br>
# **Figure 2:** Fine scale groups Japanese(1KG)&Japanese(HGDP) and Han Chinese(1KG)&Han(HGDP) and Southern Han Chinese true proportions set on interval between .199 and .201, Kinh and Chinese Dai(1KG)&Dai(HGDP) and Daur&Mongola and Naxi&Yizu true proportions set on interval between .099 and .101.; all other fine scale group true proportions set as 0. <br>100 simluation replicates completed.<br>
# Here, Summix tends to underestimate proportions of fine scale populations not equal to 0; while Summix overestimates proportions all other fine scale scale groups that have true proportions of 0. Accuracy for each fine scale group is between -.003 and .002 (Summix estimate - parameter) for all estimates.

# %%
lilsims2 <- sims[sims$P_Num == "2",]
lilsims_acc2 <- data.frame(lilsims2[,grep('accuracy', names(lilsims2))])
names(lilsims_acc2) <- gsub("_accuracy", "", names(lilsims_acc2))
boxplot(lilsims_acc2, las = 3, cex.axis = .6, tick = FALSE)
# Out:
# plot without title

# %% [markdown]
# <br><br><br>
# **Figure 3:** All fine scale groups true proportions set on interval between .0624 and .0626. <br>100 simluation replicates completed.<br>
# Here, Summix tends to underestimate Southern Han Chinese, Han Chinese(1KG)&Han(HGDP), and Chinese Dai(1KG)&Dai(HGDP) while Sumix tends to overestimate Kihn, Tu, and Daur&Mongola- no obvious trend is seen in the other fine scale populations. Accuracy for each fine scale group is between -.0015 and .001 (Summix estimate - parameter) for all estimates.

# %%
lilsims3 <- sims[sims$P_Num == "3",]
lilsims_acc3 <- data.frame(lilsims3[,grep('accuracy', names(lilsims3))])
names(lilsims_acc3) <- gsub("_accuracy", "", names(lilsims_acc3))
boxplot(lilsims_acc3, las = 3, cex.axis = .6, tick = FALSE, yaxp = c(-.004, .001, 10))
# Out:
# plot without title

# %% [markdown]
# <br><br><br>**Figure 4:** Fine scale groups Japanese(1KG)&Japanese(HGDP) and Han Chinese(1KG)&Han(HGDP) true proportions set on interval between .499 and .501. <br>
# 1000 simluation replicates completed.<br>
# Here, accuracy for each fine scale group is between -.0015 and .0016 (Summix estimate - parameter) for all estimates.

# %%
par1 <- read.table("/mnt/c/Users/adell/Desktop/Fine_Scale_Simulations_EAS_fst.002.parameter1.text", header = TRUE)
par1_acc <- data.frame(par1[,grep('accuracy', names(par1))])
names(par1_acc) <- gsub("_accuracy", "", names(par1_acc))
boxplot(par1_acc, las = 3, cex.axis = .6, tick = FALSE, yaxp = c(-.004, .001, 10))
# Out:
# plot without title

# %% [markdown]
# <br><br><br>**Figure 5:** Fine scale groups Japanese(1KG)&Japanese(HGDP) and Han Chinese(1KG)&Han(HGDP) and Southern Han Chinese true proportions set on interval between .199 and .201, Kinh and Chinese Dai(1KG)&Dai(HGDP) and Daur&Mongola and Naxi&Yizu true proportions set on interval between .099 and .101.
# <br> 1000 simluation replicates completed.<br>
# Here, accuracy for each fine scale group is between -.003 and .003 (Summix estimate - parameter) for all estimates. The largest range of accuracy is seen in Duar_Mongola, Khv(Kinh), and Chs(Southern Han Chinese).

# %%
par2 <- read.table("/mnt/c/Users/adell/Desktop/Fine_Scale_Simulations_EAS_fst.002.parameter2.text", header = TRUE)
par2_acc <- data.frame(par2[,grep('accuracy', names(par2))])
names(par2_acc) <- gsub("_accuracy", "", names(par2_acc))
boxplot(par2_acc, las = 3, cex.axis = .6, tick = FALSE)
# Out:
# plot without title

# %% [markdown]
# <br><br><br>**Figure 6:**  All fine scale groups true proportions set on interval between .0624 and .0626.<br>
# 1000 simluation replicates completed.<br>
# Here, Summix tends to underestimate Southern Han Chinese and Han Chinese(1KG)&Han(HGDP). While Sumix tends to overestimate Khv(Kihn), Tu, and Daur&Mongola, - no obvious trend is seen in the other fine scale populations. Accuracy for each fine scale group is between -.002 and .0015 (Summix estimate - parameter) for all estimates.

# %%
par3 <- read.table("/mnt/c/Users/adell/Desktop/Fine_Scale_Simulations_EAS_fst.002.parameter3.text", header = TRUE)
lilsims3 <- sims[sims$P_Num == "3",]
lilsims_acc3 <- data.frame(lilsims3[,grep('accuracy', names(lilsims3))])
par3_acc <- data.frame(par3[,grep('accuracy', names(par3))])
par3_acca <- as.data.frame(rbind(par3_acc,lilsims_acc3))
names(par3_acca) <- gsub("_accuracy", "", names(par3_acca))
boxplot(par3_acc, las = 3, cex.axis = .4, tick = FALSE)
# Out:
# plot without title

# %%
par1_2way <- read.table("/mnt/c/Users/adell/Desktop/2way_Fine_Scale_Simulations_EAS_fst.002.parameter1.text", header = TRUE)
par1_2way_acc1 <- data.frame(par1_2way[,grep('accuracy', names(par1_2way))])
names(par1_2way_acc1) <- gsub("_accuracy", "", names(par1_2way_acc1))
boxplot(par1_2way_acc1, las = 3, cex.axis = .6, tick = FALSE, yaxp = c(-.015, .015, 10)
# Out:
# plot without title

# %%
par2_2way <- read.table("/mnt/c/Users/adell/Desktop/2way_Fine_Scale_Simulations_EAS_fst.002.parameter2.text", header = TRUE)
par2_2way_acc <- data.frame(par2_2way[,grep('accuracy', names(par2_2way))])
names(par2_2way_acc) <- gsub("_accuracy", "", names(par2_2way_acc))
boxplot(par2_2way_acc, las = 3, cex.axis = .6, tick = FALSE)
# Out:
# plot without title

# %%
par3_2way <- read.table("/mnt/c/Users/adell/Desktop/2way_Fine_Scale_Simulations_EAS_fst.002.parameter3.text", header = TRUE)
par3_2way_acc <- data.frame(par3_2way[,grep('accuracy', names(par3_2way))])
names(par3_2way_acc) <- gsub("_accuracy", "", names(par3_2way_acc))
boxplot(par3_2way_acc, las = 3, cex.axis = .6, tick = FALSE)
# Out:
# plot without title
